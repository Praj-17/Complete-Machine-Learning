# %% [markdown]
# # How to read write data from html file

# %%
import pandas as pd
import html5lib

# %%
data_us = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
data_bank = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
data_phillipines = pd.read_html('https://en.wikipedia.org/wiki/List_of_World_Heritage_Sites_in_the_Philippines')

# %%
(data_us[0])  #here data is the list of data frames.
(data_bank[0])
# Out:
#                               vtePhilippines articles  \
# 0                                             History
# 1                                          Chronology
# 2                                            By topic
# 3                                           Geography
# 4   Bays Biosphere reserves Borders Climate Earthq...
# 5                                            Politics
# 6   GovernmentExecutive Cabinet Executive departme...
# 7                                          Government
# 8                                           Executive
# 9                                         Legislative
# 10                                           Judicial
# 11                                                Law
# 12                                       Intelligence
# 13                                          Uniformed
# 14  Administrative divisions Elections Foreign rel...
# 15                                            Economy
# ...

# %%
data_phillipines[3]
# Out:
#   vteLists of World Heritage Sites in Asia  \
# 0                Northern and Central Asia
# 1      Western Asia(including Arab States)
# 2                             Eastern Asia
# 3                            Southern Asia
# 4                           Southeast Asia
#
#           vteLists of World Heritage Sites in Asia.1  \
# 0  Kazakhstan Kyrgyzstan Russia (former Soviet Un...
# 1  Armenia Azerbaijan Bahrain Cyprus Georgia Iran...
# 2       China Japan Mongolia North Korea South Korea
# 3  Afghanistan Bangladesh India Nepal Pakistan Sr...
# 4  Cambodia Indonesia Laos Malaysia Myanmar Phili...
#
#    vteLists of World Heritage Sites in Asia.2
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
